# %% [markdown]
# # Private AI Face Studio — Kaggle GPU Worker
# Run with free GPU T4 x2.

# %%
# !git clone https://github.com/YOUR_USERNAME/private-ai-face-studio.git /kaggle/working/private-ai-face-studio
# %cd /kaggle/working/private-ai-face-studio/worker
# !pip install -q -r requirements.txt
# !apt-get update -qq && apt-get install -y -qq ffmpeg
import os
os.environ['API_URL'] = 'https://YOUR_BACKEND_URL.onrender.com'
os.environ['WORKER_AUTH_TOKEN'] = 'studio_worker_secret_token_2026'
# !python worker.py
